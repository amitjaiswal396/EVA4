# %%
from datetime import datetime
print("Current Date/Time: ", datetime.now())
# Out:
# Current Date/Time:  2020-03-22 00:20:06.717747

# %% [markdown]
# ****Mount Drive****

# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ****Setting Project Workspace****

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/EVA4/session9')

# %%
# !ls /content/gdrive/My\ Drive/Colab\ Notebooks/EVA4/session9/*
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/main.ipynb'
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/main.py'
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/q7_solution.ipynb'
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/Q7_solution.ipynb'
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/q7_solution.py'
#
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/dataloader':
# dataset_loader.py  data_transform.py  __pycache__
#
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/evaluation':
# __pycache__  test.py
#
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/model':
# model.py  __pycache__  quizDNN.py
#
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session9/training':
# __pycache__  train.py

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary

from dataloader import dataset_loader
from model import model
from training import train
from evaluation import test

# %% [markdown]
# ****Loading data****

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# setting up random seed and processing\ device
SEED = 1
cuda = torch.cuda.is_available()
if cuda:
    device = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    device = "cpu"
    torch.manual_seed(SEED)

# getting training data loader
trainloader = dataset_loader.get_dataloader(True, cuda)

# getting test data loader
testloader = dataset_loader.get_dataloader(False, cuda)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainloader

# get some random training images
dataiter = iter(trainloader)
#print(dataiter)
images, labels = dataiter.next()

# %% [markdown]
# ****Initializing Network Architecture****

# %%
# !pip install torchsummary
from torchsummary import summary
from model import quizDNN
mod = quizDNN.QuizDNN().to(device)
#mod = resnet.ResNet18().to(device)
summary(mod, input_size=(3, 32, 32))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#            Dropout-4           [-1, 64, 32, 32]               0
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#               ReLU-6           [-1, 64, 32, 32]               0
#        BatchNorm2d-7           [-1, 64, 32, 32]             128
#            Dropout-8           [-1, 64, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          36,864
#              ReLU-10           [-1, 64, 32, 32]               0
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#         MaxPool2d-12           [-1, 64, 16, 16]               0
#            Conv2d-13           [-1, 64, 16, 16]          36,864
#              ReLU-14           [-1, 64, 16, 16]               0
#       BatchNorm2d-15           [-1, 64, 16, 16]             128
#           Dropout-16           [-1, 64, 16, 16]               0
#            Conv2d-17           [-1, 64, 16, 16]          36,864
#              ReLU-18           [-1, 64, 16, 16]               0
#       BatchNorm2d-19           [-1, 64, 16, 16]             128
#           Dropout-20           [-1, 64, 16, 16]               0
#            Conv2d-21           [-1, 64, 16, 16]          36,864
#              ReLU-22           [-1, 64, 16, 16]               0
#       BatchNorm2d-23           [-1, 64, 16, 16]             128
#         MaxPool2d-24             [-1, 64, 8, 8]               0
#            Conv2d-25             [-1, 64, 8, 8]          36,864
#              ReLU-26             [-1, 64, 8, 8]               0
#       BatchNorm2d-27             [-1, 64, 8, 8]             128
#           Dropout-28             [-1, 64, 8, 8]               0
#            Conv2d-29             [-1, 64, 8, 8]          36,864
#              ReLU-30             [-1, 64, 8, 8]               0
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#           Dropout-32             [-1, 64, 8, 8]               0
#            Conv2d-33             [-1, 64, 8, 8]          36,864
#              ReLU-34             [-1, 64, 8, 8]               0
#       BatchNorm2d-35             [-1, 64, 8, 8]             128
# AdaptiveAvgPool2d-36             [-1, 64, 1, 1]               0
#            Linear-37                   [-1, 10]             650
# ================================================================
# Total params: 298,442
# Trainable params: 298,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 7.38
# Params size (MB): 1.14
# Estimated Total Size (MB): 8.53
# ----------------------------------------------------------------

# %% [markdown]
# ****Model training and Evaluation****

# %%
from training import train
from evaluation import test
# loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(mod.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005)

# Model Training and Evaluation
for epoch in range(0, 25):
    train.train(mod, device, trainloader, optimizer, epoch, criterion)
    test.test(mod, device, testloader, criterion)
# Out:
# epoch=0 Loss=1.7865104675292969 Batch_id=390 Accuracy=29.57: 100%|██████████| 391/391 [00:39<00:00,  9.85it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0136, Accuracy: 3467/10000 (34.7%)
# epoch=1 Loss=1.4654613733291626 Batch_id=390 Accuracy=39.86: 100%|██████████| 391/391 [00:39<00:00,  9.85it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0130, Accuracy: 4022/10000 (40.2%)
# epoch=2 Loss=1.5068166255950928 Batch_id=390 Accuracy=44.29: 100%|██████████| 391/391 [00:39<00:00,  9.78it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0125, Accuracy: 4460/10000 (44.6%)
# epoch=3 Loss=1.5719305276870728 Batch_id=390 Accuracy=47.77: 100%|██████████| 391/391 [00:39<00:00,  9.85it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0123, Accuracy: 4744/10000 (47.4%)
# epoch=4 Loss=1.440434217453003 Batch_id=390 Accuracy=50.31: 100%|██████████| 391/391 [00:39<00:00,  9.88it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0108, Accuracy: 5282/10000 (52.8%)
# epoch=5 Loss=1.2576274871826172 Batch_id=390 Accuracy=52.36: 100%|██████████| 391/391 [00:40<00:00,  9.76it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0115, Accuracy: 5122/10000 (51.2%)
# epoch=6 Loss=1.1494653224945068 Batch_id=390 Accuracy=53.82: 100%|██████████| 391/391 [00:39<00:00,  9.83it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0097, Accuracy: 5686/10000 (56.9%)
# epoch=7 Loss=1.4337174892425537 Batch_id=390 Accuracy=55.58: 100%|██████████| 391/391 [00:39<00:00,  9.92it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0091, Accuracy: 5931/10000 (59.3%)
# epoch=8 Loss=1.2493318319320679 Batch_id=390 Accuracy=57.07: 100%|██████████| 391/391 [00:39<00:00,  9.88it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0093, Accuracy: 6012/10000 (60.1%)
# epoch=9 Loss=1.2457365989685059 Batch_id=390 Accuracy=58.14: 100%|██████████| 391/391 [00:39<00:00,  9.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0092, Accuracy: 6050/10000 (60.5%)
# epoch=10 Loss=1.0329607725143433 Batch_id=390 Accuracy=59.62: 100%|██████████| 391/391 [00:39<00:00,  9.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0089, Accuracy: 6119/10000 (61.2%)
# epoch=11 Loss=1.1789615154266357 Batch_id=178 Accuracy=60.42:  45%|████▌     | 177/391 [00:18<00:22,  9.34it/s]
